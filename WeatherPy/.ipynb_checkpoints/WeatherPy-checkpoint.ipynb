# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 582

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=Metric&appid=" + weather_api_key


# Define an empty list to fetch the weather data for each city
city_data = []

#Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
   
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                         })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | cabo san lucas
# Processing Record 3 of Set 1 | vadso
# Processing Record 4 of Set 1 | nemuro
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | happy valley-goose bay
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | keflavik
# Processing Record 9 of Set 1 | police
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | puerto natales
# Processing Record 14 of Set 1 | whitehorse
# Processing Record 15 of Set 1 | bardai
# Processing Record 16 of Set 1 | chernyshevskiy
# Processing Record 17 of Set 1 | queenstown
# Processing Record 18 of Set 1 | aldan
# Processing Record 19 of Set 1 | enewetak
# Processing Record 20 of Set 1 | bikenibeu village
# Processing Record 21 of Set 1 | tamiahua
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | kingston
# Processing Record 24 of Set 1 | marudi
# City not found. Skipping...
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | blackmans bay
# Processing Record 27 of Set 1 | mount gambier
# Processing Record 28 of Set 1 | cockburn town
# Processing Record 29 of Set 1 | ponto novo
# Processing Record 30 of Set 1 | grytviken
# Processing Record 31 of Set 1 | dryden
# Processing Record 32 of Set 1 | paracuru
# Processing Record 33 of Set 1 | al 'alamayn
# City not found. Skipping...
# Processing Record 34 of Set 1 | tabou
# Processing Record 35 of Set 1 | rancho palos verdes
# Processing Record 36 of Set 1 | san patricio
# Processing Record 37 of Set 1 | tazacorte
# Processing Record 38 of Set 1 | crane
# Processing Record 39 of Set 1 | ketchikan
# Processing Record 40 of Set 1 | celestun
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | port lincoln
# Processing Record 43 of Set 1 | afaahiti
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | portland
# Processing Record 47 of Set 1 | kirkwall
# Processing Record 48 of Set 1 | floro
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | lompoc
# Processing Record 0 of Set 2 | quellon
# Processing Record 1 of Set 2 | phang nga
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | chonchi
# Processing Record 4 of Set 2 | fort st. john
# Processing Record 5 of Set 2 | invercargill
# Processing Record 6 of Set 2 | minas de marcona
# Processing Record 7 of Set 2 | constantia
# Processing Record 8 of Set 2 | ikongo
# Processing Record 9 of Set 2 | fale old settlement
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 2 | wailua homesteads
# Processing Record 14 of Set 2 | katima mulilo
# Processing Record 15 of Set 2 | ulsteinvik
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | nelson bay
# Processing Record 18 of Set 2 | saudarkrokur
# Processing Record 19 of Set 2 | tamanrasset
# Processing Record 20 of Set 2 | kapa'a
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | margaret river
# Processing Record 23 of Set 2 | lihue
# Processing Record 24 of Set 2 | anadyr
# Processing Record 25 of Set 2 | college
# Processing Record 26 of Set 2 | edinburgh of the seven seas
# Processing Record 27 of Set 2 | tvoroyri
# Processing Record 28 of Set 2 | camocim
# Processing Record 29 of Set 2 | tazovsky
# Processing Record 30 of Set 2 | kulia village
# City not found. Skipping...
# Processing Record 31 of Set 2 | labrador city
# Processing Record 32 of Set 2 | aasiaat
# Processing Record 33 of Set 2 | daru
# Processing Record 34 of Set 2 | letlhakane
# Processing Record 35 of Set 2 | port saint john's
# Processing Record 36 of Set 2 | nguigmi
# Processing Record 37 of Set 2 | kendari
# Processing Record 38 of Set 2 | san agustin de valle fertil
# Processing Record 39 of Set 2 | thunder bay
# Processing Record 40 of Set 2 | chardara
# Processing Record 41 of Set 2 | juneau
# Processing Record 42 of Set 2 | kerikeri
# Processing Record 43 of Set 2 | hotan
# Processing Record 44 of Set 2 | jackson
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 47 of Set 2 | khandyga
# Processing Record 48 of Set 2 | castillos
# Processing Record 49 of Set 2 | yemva
# Processing Record 0 of Set 3 | saldanha
# Processing Record 1 of Set 3 | lauro de freitas
# Processing Record 2 of Set 3 | papatowai
# Processing Record 3 of Set 3 | inhambane
# Processing Record 4 of Set 3 | ust'-kut
# Processing Record 5 of Set 3 | glendive
# Processing Record 6 of Set 3 | ji'an
# Processing Record 7 of Set 3 | bedford
# Processing Record 8 of Set 3 | porto novo
# Processing Record 9 of Set 3 | siran
# Processing Record 10 of Set 3 | la gi
# Processing Record 11 of Set 3 | fuerte olimpo
# Processing Record 12 of Set 3 | waitangi
# Processing Record 13 of Set 3 | udachny
# Processing Record 14 of Set 3 | ust-nera
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | barcelos
# Processing Record 17 of Set 3 | ocean shores
# Processing Record 18 of Set 3 | neyriz
# Processing Record 19 of Set 3 | red lion
# Processing Record 20 of Set 3 | tharad
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | hawaiian paradise park
# Processing Record 24 of Set 3 | nieuw amsterdam
# Processing Record 25 of Set 3 | sisimiut
# Processing Record 26 of Set 3 | oranjemund
# Processing Record 27 of Set 3 | zhangjiakou
# Processing Record 28 of Set 3 | qarah bagh
# Processing Record 29 of Set 3 | waingapu
# Processing Record 30 of Set 3 | adler
# Processing Record 31 of Set 3 | talnakh
# Processing Record 32 of Set 3 | olonkinbyen
# Processing Record 33 of Set 3 | boca do acre
# Processing Record 34 of Set 3 | anjozorobe
# Processing Record 35 of Set 3 | nuku'alofa
# Processing Record 36 of Set 3 | pisco
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | hasaki
# Processing Record 39 of Set 3 | kani keli
# Processing Record 40 of Set 3 | woodland park
# Processing Record 41 of Set 3 | petoskey
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | alghero
# Processing Record 44 of Set 3 | la sarre
# Processing Record 45 of Set 3 | tashla
# Processing Record 46 of Set 3 | west island
# Processing Record 47 of Set 3 | bambanglipuro
# Processing Record 48 of Set 3 | zarghun shahr
# Processing Record 49 of Set 3 | ivoti
# Processing Record 0 of Set 4 | ta`u
# Processing Record 1 of Set 4 | port alfred
# Processing Record 2 of Set 4 | campos belos
# Processing Record 3 of Set 4 | letterkenny
# Processing Record 4 of Set 4 | cova figueira
# Processing Record 5 of Set 4 | kapit
# Processing Record 6 of Set 4 | thinadhoo
# Processing Record 7 of Set 4 | sile
# Processing Record 8 of Set 4 | dudinka
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | flying fish cove
# Processing Record 11 of Set 4 | aibak
# Processing Record 12 of Set 4 | mugia
# Processing Record 13 of Set 4 | mount isa
# Processing Record 14 of Set 4 | ghosi
# Processing Record 15 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 16 of Set 4 | khemis miliana
# Processing Record 17 of Set 4 | bilibino
# Processing Record 18 of Set 4 | villa gesell
# Processing Record 19 of Set 4 | upata
# Processing Record 20 of Set 4 | salur
# Processing Record 21 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | sao jose da coroa grande
# Processing Record 24 of Set 4 | alice springs
# Processing Record 25 of Set 4 | jalalaqsi
# Processing Record 26 of Set 4 | atafu village
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | egilsstadir
# Processing Record 29 of Set 4 | novodvinsk
# Processing Record 30 of Set 4 | berdigestyakh
# Processing Record 31 of Set 4 | fujikawaguchiko
# Processing Record 32 of Set 4 | souillac
# Processing Record 33 of Set 4 | malango
# Processing Record 34 of Set 4 | pecos
# Processing Record 35 of Set 4 | rongelap
# Processing Record 36 of Set 4 | axim
# Processing Record 37 of Set 4 | nar'yan-mar
# Processing Record 38 of Set 4 | saipan
# Processing Record 39 of Set 4 | qaqortoq
# Processing Record 40 of Set 4 | tangalle
# Processing Record 41 of Set 4 | nova sintra
# Processing Record 42 of Set 4 | stanley
# Processing Record 43 of Set 4 | ugoofaaru
# Processing Record 44 of Set 4 | kalevala
# Processing Record 45 of Set 4 | puerto ayora
# Processing Record 46 of Set 4 | sept-iles
# Processing Record 47 of Set 4 | al kharijah
# Processing Record 48 of Set 4 | cianorte
# Processing Record 49 of Set 4 | usogorsk
# Processing Record 0 of Set 5 | santo antonio do ica
# Processing Record 1 of Set 5 | fukuecho
# Processing Record 2 of Set 5 | port elizabeth
# Processing Record 3 of Set 5 | walvis bay
# Processing Record 4 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 5 of Set 5 | gadzhiyevo
# Processing Record 6 of Set 5 | luling
# Processing Record 7 of Set 5 | nova vicosa
# Processing Record 8 of Set 5 | isafjordur
# Processing Record 9 of Set 5 | opuwo
# Processing Record 10 of Set 5 | selfoss
# Processing Record 11 of Set 5 | arawa
# Processing Record 12 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 5 | newman
# Processing Record 14 of Set 5 | thompson
# Processing Record 15 of Set 5 | maceio
# Processing Record 16 of Set 5 | okahandja
# Processing Record 17 of Set 5 | jayapura
# Processing Record 18 of Set 5 | shimoda
# Processing Record 19 of Set 5 | byron bay
# Processing Record 20 of Set 5 | new norfolk
# Processing Record 21 of Set 5 | harnosand
# Processing Record 22 of Set 5 | puerto deseado
# Processing Record 23 of Set 5 | richards bay
# Processing Record 24 of Set 5 | rayon
# Processing Record 25 of Set 5 | vernon
# Processing Record 26 of Set 5 | coari
# Processing Record 27 of Set 5 | el calafate
# Processing Record 28 of Set 5 | greymouth
# Processing Record 29 of Set 5 | tsiombe
# Processing Record 30 of Set 5 | fort bragg
# Processing Record 31 of Set 5 | adh dhibiyah
# City not found. Skipping...
# Processing Record 32 of Set 5 | plastun
# Processing Record 33 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 34 of Set 5 | tonga
# Processing Record 35 of Set 5 | hoemul-li
# Processing Record 36 of Set 5 | giado
# Processing Record 37 of Set 5 | jiwani
# Processing Record 38 of Set 5 | khorixas
# Processing Record 39 of Set 5 | utrik
# Processing Record 40 of Set 5 | arno
# Processing Record 41 of Set 5 | mata-utu
# Processing Record 42 of Set 5 | carnarvon
# Processing Record 43 of Set 5 | abaza
# Processing Record 44 of Set 5 | izazi
# Processing Record 45 of Set 5 | geraldton
# Processing Record 46 of Set 5 | olinda
# Processing Record 47 of Set 5 | katsuren-haebaru
# Processing Record 48 of Set 5 | zhezqazghan
# Processing Record 49 of Set 5 | antalaha
# Processing Record 0 of Set 6 | tolanaro
# Processing Record 1 of Set 6 | peniche
# Processing Record 2 of Set 6 | mukalla
# Processing Record 3 of Set 6 | uyuni
# Processing Record 4 of Set 6 | moengo
# Processing Record 5 of Set 6 | robore
# Processing Record 6 of Set 6 | port mathurin
# Processing Record 7 of Set 6 | kavieng
# Processing Record 8 of Set 6 | vilyuchinsk
# Processing Record 9 of Set 6 | revda
# Processing Record 10 of Set 6 | west fargo
# Processing Record 11 of Set 6 | masterton
# Processing Record 12 of Set 6 | bad konigshofen im grabfeld
# Processing Record 13 of Set 6 | brisas de zicatela
# Processing Record 14 of Set 6 | lido adriano
# Processing Record 15 of Set 6 | st. john's
# Processing Record 16 of Set 6 | brokopondo
# Processing Record 17 of Set 6 | klyuchi
# Processing Record 18 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 19 of Set 6 | kidal
# Processing Record 20 of Set 6 | redencao
# Processing Record 21 of Set 6 | badger
# Processing Record 22 of Set 6 | hajipur
# Processing Record 23 of Set 6 | vila velha
# Processing Record 24 of Set 6 | mount pearl
# Processing Record 25 of Set 6 | sarina
# Processing Record 26 of Set 6 | dolinsk
# Processing Record 27 of Set 6 | zhelezinka
# Processing Record 28 of Set 6 | tura
# Processing Record 29 of Set 6 | cromer
# Processing Record 30 of Set 6 | ngawi
# Processing Record 31 of Set 6 | ad dabbah
# Processing Record 32 of Set 6 | molteno
# Processing Record 33 of Set 6 | iskateley
# Processing Record 34 of Set 6 | lebu
# Processing Record 35 of Set 6 | zinacatepec
# Processing Record 36 of Set 6 | yokadouma
# Processing Record 37 of Set 6 | cadale
# Processing Record 38 of Set 6 | kapuskasing
# Processing Record 39 of Set 6 | shillong
# Processing Record 40 of Set 6 | aljezur
# Processing Record 41 of Set 6 | san juan de uraba
# Processing Record 42 of Set 6 | faya-largeau
# Processing Record 43 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 44 of Set 6 | el nido
# Processing Record 45 of Set 6 | yaren
# Processing Record 46 of Set 6 | guercif
# Processing Record 47 of Set 6 | vad
# Processing Record 48 of Set 6 | sant lluis
# Processing Record 49 of Set 6 | nobres
# Processing Record 0 of Set 7 | longfeng
# Processing Record 1 of Set 7 | maiduguri
# Processing Record 2 of Set 7 | ballina
# Processing Record 3 of Set 7 | hami
# Processing Record 4 of Set 7 | novyye lyady
# Processing Record 5 of Set 7 | tromso
# Processing Record 6 of Set 7 | nogliki
# Processing Record 7 of Set 7 | boiling springs
# Processing Record 8 of Set 7 | romblon
# Processing Record 9 of Set 7 | jahazpur
# Processing Record 10 of Set 7 | sassandra
# Processing Record 11 of Set 7 | okhotsk
# Processing Record 12 of Set 7 | jose de freitas
# Processing Record 13 of Set 7 | boyolangu
# Processing Record 14 of Set 7 | karwar
# Processing Record 15 of Set 7 | wynyard
# Processing Record 16 of Set 7 | santa fe do sul
# Processing Record 17 of Set 7 | colonia
# Processing Record 18 of Set 7 | chiredzi
# Processing Record 19 of Set 7 | tuy hoa
# Processing Record 20 of Set 7 | montepuez
# Processing Record 21 of Set 7 | suntar
# Processing Record 22 of Set 7 | hobyo
# Processing Record 23 of Set 7 | prince rupert
# Processing Record 24 of Set 7 | nicoya
# Processing Record 25 of Set 7 | qusmuryn
# Processing Record 26 of Set 7 | pathardi
# Processing Record 27 of Set 7 | ambodifotatra
# Processing Record 28 of Set 7 | dolbeau-mistassini
# Processing Record 29 of Set 7 | wamba
# Processing Record 30 of Set 7 | dalnerechensk
# Processing Record 31 of Set 7 | la ronge
# Processing Record 32 of Set 7 | ancud
# Processing Record 33 of Set 7 | lipayran
# Processing Record 34 of Set 7 | macau
# Processing Record 35 of Set 7 | la'ie
# Processing Record 36 of Set 7 | bandon
# Processing Record 37 of Set 7 | la mira
# Processing Record 38 of Set 7 | golere
# Processing Record 39 of Set 7 | nova venecia
# Processing Record 40 of Set 7 | bolnisi
# Processing Record 41 of Set 7 | nadym
# Processing Record 42 of Set 7 | aleg
# Processing Record 43 of Set 7 | mejit
# Processing Record 44 of Set 7 | polyarnyy
# Processing Record 45 of Set 7 | haiku-pauwela
# Processing Record 46 of Set 7 | fortuna
# Processing Record 47 of Set 7 | mokhsogollokh
# Processing Record 48 of Set 7 | gizo
# Processing Record 49 of Set 7 | conception bay south
# Processing Record 0 of Set 8 | pitimbu
# Processing Record 1 of Set 8 | marka
# Processing Record 2 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 3 of Set 8 | buka
# Processing Record 4 of Set 8 | champerico
# Processing Record 5 of Set 8 | belgrade
# Processing Record 6 of Set 8 | ribas do rio pardo
# Processing Record 7 of Set 8 | kulhudhuffushi
# Processing Record 8 of Set 8 | neryungri
# Processing Record 9 of Set 8 | shangri-la
# City not found. Skipping...
# Processing Record 10 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 11 of Set 8 | altayskoye
# Processing Record 12 of Set 8 | carutapera
# Processing Record 13 of Set 8 | katsuura
# Processing Record 14 of Set 8 | saubara
# Processing Record 15 of Set 8 | kupang
# Processing Record 16 of Set 8 | karatau
# Processing Record 17 of Set 8 | shira
# Processing Record 18 of Set 8 | novaya igirma
# Processing Record 19 of Set 8 | garissa
# Processing Record 20 of Set 8 | lodja
# Processing Record 21 of Set 8 | pacific grove
# Processing Record 22 of Set 8 | ngaoundere
# Processing Record 23 of Set 8 | pokaran
# Processing Record 24 of Set 8 | kambove
# Processing Record 25 of Set 8 | maintirano
# Processing Record 26 of Set 8 | abu dhabi
# Processing Record 27 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 8 | bubaque
# Processing Record 29 of Set 8 | ermoupolis
# Processing Record 30 of Set 8 | island harbour
# Processing Record 31 of Set 8 | mgandu
# Processing Record 32 of Set 8 | verkhnevilyuysk
# Processing Record 33 of Set 8 | tyukhtet
# Processing Record 34 of Set 8 | hanceville
# Processing Record 35 of Set 8 | hinton
# Processing Record 36 of Set 8 | bluefields
# Processing Record 37 of Set 8 | oliva de la frontera
# Processing Record 38 of Set 8 | vredendal
# Processing Record 39 of Set 8 | boa vista
# Processing Record 40 of Set 8 | victorica
# Processing Record 41 of Set 8 | kota kinabalu
# Processing Record 42 of Set 8 | nema
# Processing Record 43 of Set 8 | aegina
# Processing Record 44 of Set 8 | sao tome
# Processing Record 45 of Set 8 | cannonvale
# Processing Record 46 of Set 8 | mahibadhoo
# Processing Record 47 of Set 8 | sao joao da barra
# Processing Record 48 of Set 8 | tommot
# Processing Record 49 of Set 8 | golyshmanovo
# Processing Record 0 of Set 9 | launceston
# Processing Record 1 of Set 9 | kenai
# Processing Record 2 of Set 9 | kultali
# City not found. Skipping...
# Processing Record 3 of Set 9 | nouadhibou
# Processing Record 4 of Set 9 | aykhal
# Processing Record 5 of Set 9 | turar ryskulov
# Processing Record 6 of Set 9 | cat ba
# City not found. Skipping...
# Processing Record 7 of Set 9 | suixi
# Processing Record 8 of Set 9 | wundanyi
# Processing Record 9 of Set 9 | codrington
# Processing Record 10 of Set 9 | tell city
# Processing Record 11 of Set 9 | energetik
# Processing Record 12 of Set 9 | kota belud
# Processing Record 13 of Set 9 | sur
# Processing Record 14 of Set 9 | uturoa
# Processing Record 15 of Set 9 | lazaro cardenas
# Processing Record 16 of Set 9 | kwang binh
# Processing Record 17 of Set 9 | flin flon
# Processing Record 18 of Set 9 | langepas
# Processing Record 19 of Set 9 | le port
# Processing Record 20 of Set 9 | la villa del rosario
# Processing Record 21 of Set 9 | nukunonu
# City not found. Skipping...
# Processing Record 22 of Set 9 | fort mcmurray
# Processing Record 23 of Set 9 | tralee
# Processing Record 24 of Set 9 | susuman
# Processing Record 25 of Set 9 | kaynarca
# Processing Record 26 of Set 9 | belyy yar
# Processing Record 27 of Set 9 | mirandela
# Processing Record 28 of Set 9 | centralia
# Processing Record 29 of Set 9 | tintafor
# Processing Record 30 of Set 9 | heyuan
# Processing Record 31 of Set 9 | chui
# Processing Record 32 of Set 9 | olyokminsk
# Processing Record 33 of Set 9 | acapulco de juarez
# Processing Record 34 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 35 of Set 9 | real
# Processing Record 36 of Set 9 | hilo
# Processing Record 37 of Set 9 | darnah
# Processing Record 38 of Set 9 | qal'at bishah
# City not found. Skipping...
# Processing Record 39 of Set 9 | praia da vitoria
# Processing Record 40 of Set 9 | alta
# Processing Record 41 of Set 9 | remire-montjoly
# Processing Record 42 of Set 9 | castanos
# Processing Record 43 of Set 9 | arkadak
# Processing Record 44 of Set 9 | tidjikja
# Processing Record 45 of Set 9 | karymskoye
# Processing Record 46 of Set 9 | mae chan
# Processing Record 47 of Set 9 | meizhou
# Processing Record 48 of Set 9 | pagsanghan
# Processing Record 49 of Set 9 | kalianget
# Processing Record 0 of Set 10 | setti fatma
# City not found. Skipping...
# Processing Record 1 of Set 10 | valley center
# Processing Record 2 of Set 10 | bamboo flat
# Processing Record 3 of Set 10 | preobrazheniye
# Processing Record 4 of Set 10 | coquimbo
# Processing Record 5 of Set 10 | rio grande
# Processing Record 6 of Set 10 | zheleznodorozhnyy
# Processing Record 7 of Set 10 | kristiansund
# Processing Record 8 of Set 10 | namibe
# Processing Record 9 of Set 10 | price
# Processing Record 10 of Set 10 | kairouan
# Processing Record 11 of Set 10 | naze
# Processing Record 12 of Set 10 | vorgashor
# Processing Record 13 of Set 10 | veraval
# Processing Record 14 of Set 10 | gua musang
# Processing Record 15 of Set 10 | banda aceh
# Processing Record 16 of Set 10 | san julian
# Processing Record 17 of Set 10 | wacheng
# Processing Record 18 of Set 10 | qapqal
# City not found. Skipping...
# Processing Record 19 of Set 10 | kayangel
# Processing Record 20 of Set 10 | waddan
# Processing Record 21 of Set 10 | nehe
# Processing Record 22 of Set 10 | zabol
# Processing Record 23 of Set 10 | zhob
# Processing Record 24 of Set 10 | alness
# Processing Record 25 of Set 10 | kavaratti
# Processing Record 26 of Set 10 | quitilipi
# Processing Record 27 of Set 10 | tindouf
# Processing Record 28 of Set 10 | mitu
# Processing Record 29 of Set 10 | sonamura
# Processing Record 30 of Set 10 | comayagua
# Processing Record 31 of Set 10 | raahe
# Processing Record 32 of Set 10 | gamba
# Processing Record 33 of Set 10 | hailar
# Processing Record 34 of Set 10 | pemangkat
# Processing Record 35 of Set 10 | barra do corda
# Processing Record 36 of Set 10 | ati
# Processing Record 37 of Set 10 | altai
# Processing Record 38 of Set 10 | gaigeturi
# Processing Record 39 of Set 10 | inyonga
# Processing Record 40 of Set 10 | lloydminster
# Processing Record 41 of Set 10 | malazgirt
# Processing Record 42 of Set 10 | tchintabaraden
# Processing Record 43 of Set 10 | myingyan
# Processing Record 44 of Set 10 | bonthe
# Processing Record 45 of Set 10 | phon
# Processing Record 46 of Set 10 | wewak
# Processing Record 47 of Set 10 | satipo
# Processing Record 48 of Set 10 | kimry
# Processing Record 49 of Set 10 | huetamo de nunez
# Processing Record 0 of Set 11 | gandajika
# Processing Record 1 of Set 11 | kyaukse
# Processing Record 2 of Set 11 | la passe
# Processing Record 3 of Set 11 | ribeirao da ilha
# Processing Record 4 of Set 11 | broome
# Processing Record 5 of Set 11 | skoghall
# Processing Record 6 of Set 11 | yuzhno-sukhokumsk
# Processing Record 7 of Set 11 | puerto carreno
# Processing Record 8 of Set 11 | atherton
# Processing Record 9 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 10 of Set 11 | necochea
# Processing Record 11 of Set 11 | pangoa
# Processing Record 12 of Set 11 | nyurba
# Processing Record 13 of Set 11 | palikir - national government center
# Processing Record 14 of Set 11 | severo-yeniseyskiy
# Processing Record 15 of Set 11 | muri
# Processing Record 16 of Set 11 | acajutla
# Processing Record 17 of Set 11 | smara
# Processing Record 18 of Set 11 | tutoia
# Processing Record 19 of Set 11 | buenavista del norte
# Processing Record 20 of Set 11 | abu jibeha
# Processing Record 21 of Set 11 | takamaka
# City not found. Skipping...
# Processing Record 22 of Set 11 | kodiak
# Processing Record 23 of Set 11 | fort-shevchenko
# Processing Record 24 of Set 11 | nyala
# Processing Record 25 of Set 11 | whitehaven
# Processing Record 26 of Set 11 | magadan
# Processing Record 27 of Set 11 | wau
# Processing Record 28 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 29 of Set 11 | kailua-kona
# Processing Record 30 of Set 11 | conde
# Processing Record 31 of Set 11 | gobabis
# Processing Record 32 of Set 11 | antofagasta
# Processing Record 33 of Set 11 | nanakuli
# Processing Record 34 of Set 11 | pindushi
# Processing Record 35 of Set 11 | pariang
# City not found. Skipping...
# Processing Record 36 of Set 11 | chibougamau
# Processing Record 37 of Set 11 | hithadhoo
# Processing Record 38 of Set 11 | santa vitoria do palmar
# Processing Record 39 of Set 11 | alpena
# Processing Record 40 of Set 11 | curuca
# Processing Record 41 of Set 11 | manokwari
# Processing Record 42 of Set 11 | cestos city
# Processing Record 43 of Set 11 | muli
# Processing Record 44 of Set 11 | newton
# Processing Record 45 of Set 11 | 'ibri
# City not found. Skipping...
# Processing Record 46 of Set 11 | canon city
# Processing Record 47 of Set 11 | weno
# Processing Record 48 of Set 11 | calabozo
# Processing Record 49 of Set 11 | collie
# Processing Record 0 of Set 12 | markovo
# Processing Record 1 of Set 12 | east end
# Processing Record 2 of Set 12 | ostersund
# Processing Record 3 of Set 12 | marsh harbour
# Processing Record 4 of Set 12 | swakopmund
# Processing Record 5 of Set 12 | kiunga
# Processing Record 6 of Set 12 | coahuayana de hidalgo
# Processing Record 7 of Set 12 | muisne
# Processing Record 8 of Set 12 | ash shafa
# City not found. Skipping...
# Processing Record 9 of Set 12 | valparaiso
# Processing Record 10 of Set 12 | callao
# Processing Record 11 of Set 12 | nenjiang
# Processing Record 12 of Set 12 | cole harbour
# Processing Record 13 of Set 12 | cidreira
# Processing Record 14 of Set 12 | ishikawa
# Processing Record 15 of Set 12 | acarau
# Processing Record 16 of Set 12 | lospalos
# Processing Record 17 of Set 12 | vilhena
# Processing Record 18 of Set 12 | eyl
# Processing Record 19 of Set 12 | kone
# Processing Record 20 of Set 12 | grand falls-windsor
# Processing Record 21 of Set 12 | liboro
# Processing Record 22 of Set 12 | totness
# Processing Record 23 of Set 12 | horta
# Processing Record 24 of Set 12 | yulinshi
# Processing Record 25 of Set 12 | glace bay
# Processing Record 26 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 27 of Set 12 | moscow
# Processing Record 28 of Set 12 | zhaotong
# Processing Record 29 of Set 12 | totskoye
# Processing Record 30 of Set 12 | fengxiang
# Processing Record 31 of Set 12 | chashniki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          552
# Lat           552
# Lng           552
# Max Temp      552
# Humidity      552
# Cloudiness    552
# Wind Speed    552
# Country       552
# Date          552
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      7.62        91         100
# 1     cabo san lucas  22.8909 -109.9124     30.90        43           3
# 2              vadso  70.0744   29.7487     10.49        76           0
# 3             nemuro  43.3236  145.5750      3.17        81          18
# 4        yellowknife  62.4560 -114.3525     15.31        36          40
#
#    Wind Speed Country        Date
# 0       18.03      TF  1683824655
# 1        5.14      MX  1683824394
# 2        1.54      NO  1683824459
# 3        5.51      JP  1683824656
# 4        5.66      CA  1683824656

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      7.62        91         100
# 1           cabo san lucas  22.8909 -109.9124     30.90        43           3
# 2                    vadso  70.0744   29.7487     10.49        76           0
# 3                   nemuro  43.3236  145.5750      3.17        81          18
# 4              yellowknife  62.4560 -114.3525     15.31        36          40
#
#          Wind Speed Country        Date
# City_ID
# 0             18.03      TF  1683824655
# 1              5.14      MX  1683824394
# 2              1.54      NO  1683824459
# 3              5.51      JP  1683824656
# 4              5.66      CA  1683824656

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = city_data_df['Lat']
y_axis = city_data_df['Max Temp']
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
#today's date
today = time.gmtime()
today_formatted = time.strftime("%Y-%m-%d", today)
plt.title(f"City Latitude vs. Max Temperature ({today_formatted})")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Max Temperature (C)")


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
y_axis = city_data_df['Humidity']
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({today_formatted})")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
y_axis = city_data_df['Cloudiness']
plt.scatter(x_axis, y_axis, edgecolors="black")


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({today_formatted})")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
y_axis = city_data_df['Wind Speed']
plt.scatter(x_axis, y_axis, edgecolors="black")


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({today_formatted})")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                cabo san lucas  22.8909 -109.9124     30.90        43
# 2                         vadso  70.0744   29.7487     10.49        76
# 3                        nemuro  43.3236  145.5750      3.17        81
# 4                   yellowknife  62.4560 -114.3525     15.31        36
# 5        happy valley-goose bay  53.3168  -60.3315     10.17        23
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                 3        5.14      MX  1683824394
# 2                 0        1.54      NO  1683824459
# 3                18        5.51      JP  1683824656
# 4                40        5.66      CA  1683824656
# 5                20        4.63      CA  1683824656

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      7.62        91         100
# 9                adamstown -25.0660 -130.1015     21.52        53          93
# 11                 ushuaia -54.8000  -68.3000      6.81        81          75
# 12          puerto natales -51.7236  -72.4875     10.25        71          75
# 16              queenstown -31.8976   26.8753     14.46        53          54
#
#          Wind Speed Country        Date
# City_ID
# 0             18.03      TF  1683824655
# 9              8.80      PN  1683824663
# 11             1.03      AR  1683824664
# 12             1.03      CL  1683824606
# 16             1.72      ZA  1683824667

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Max Temp']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.text(8, -10, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is -0.821506243515974

# %%
# Linear regression on Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Max Temp']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.text(-55, 30, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.817233277993287

# %% [markdown]
# ## Linear relationship
# ### Northern Hemisphere data
# * The r value for the northern hemisphere data shows a strong *negative* correlation as the r value is almost -1
# * The father north from the equator, the lower the maximum temperature
#
# ### Souther Hemisphere data
# * The r value for the southern hemisphere data shows a strong *positive* correlation as the r value is almost 1
# * The closer the city is to the equator, the higher the maximum temperature

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Humidity']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.text(40, 15, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.11937670942323875

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Humidity']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.text(-50, 20, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.01894930875619609

# %% [markdown]
# ## Linear Relationship
#
# ### Northern Hemisphere
# - The data for the nothern hemisphere has a very slight positive correlation as the r value of the line of best fit is very close to 0.
# - The more north from the equator the city is, it appears that the humidity is *slightly* higher than cities closer to the equator
#
# ### Southern Hemisphere
# - The data for the southern hemisphere has almost no correlation as the r value is even closer to 0 than the northern hemisphere data.
# - The humidity data as a whole appears to be rather inconclusive as there is no obvious trend between the distance from the equator and humidity for both north and south hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Cloudiness']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.text(50, 10, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is -0.004866617611318711

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Cloudiness']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.text(-50, 20, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.08006096402045165

# %% [markdown]
# ## Linear Relationship
# - The data for both the northern and southern hemispheres appears to show no correlation between the distance from the equator and the level of cloudiness.
# - There are cloudiness levels at both extremes regardless of latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Wind Speed']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.text(50, 10, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.0131010433303601

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Wind Speed']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.text(-50, 10, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is -0.13154646198143383

# %% [markdown]
# ## Linear Relationship
# - The data for both the northern and southern hemispheres appears to show no correlation between the distance from the equator and wind speed. There are speeds ranging from still to very windy at all latitudes.
