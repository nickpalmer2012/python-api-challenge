# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 608

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=Metric&appid=" + weather_api_key


# Define an empty list to fetch the weather data for each city
city_data = []

#Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
   
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                         })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | hammerfest
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | talcahuano
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | greymouth
# Processing Record 8 of Set 1 | kamloops
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | laoag
# Processing Record 12 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 13 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 14 of Set 1 | margaret river
# Processing Record 15 of Set 1 | mizunami
# Processing Record 16 of Set 1 | bilibino
# Processing Record 17 of Set 1 | tolanaro
# Processing Record 18 of Set 1 | berezovyy
# Processing Record 19 of Set 1 | manjeshvar
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | odda
# Processing Record 22 of Set 1 | kupang
# Processing Record 23 of Set 1 | vuktyl
# Processing Record 24 of Set 1 | vernon
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | rotonda west
# Processing Record 27 of Set 1 | mangochi
# Processing Record 28 of Set 1 | bamboo flat
# Processing Record 29 of Set 1 | nyandoma
# Processing Record 30 of Set 1 | kingston
# Processing Record 31 of Set 1 | tshabong
# Processing Record 32 of Set 1 | lihue
# Processing Record 33 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 34 of Set 1 | naze
# Processing Record 35 of Set 1 | blackmans bay
# Processing Record 36 of Set 1 | maitum
# Processing Record 37 of Set 1 | stanley
# Processing Record 38 of Set 1 | papatowai
# Processing Record 39 of Set 1 | west island
# Processing Record 40 of Set 1 | jincheng
# Processing Record 41 of Set 1 | invercargill
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | pacific grove
# Processing Record 44 of Set 1 | dudinka
# Processing Record 45 of Set 1 | isafjordur
# Processing Record 46 of Set 1 | banda aceh
# Processing Record 47 of Set 1 | waitangi
# Processing Record 48 of Set 1 | udachny
# Processing Record 49 of Set 1 | inekar
# City not found. Skipping...
# Processing Record 50 of Set 1 | bathurst city centre
# City not found. Skipping...
# Processing Record 0 of Set 2 | albany
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | tazovsky
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | west plains
# Processing Record 5 of Set 2 | opuwo
# Processing Record 6 of Set 2 | port mathurin
# Processing Record 7 of Set 2 | qaqortoq
# Processing Record 8 of Set 2 | colonia
# Processing Record 9 of Set 2 | dylym
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | arkalyk
# Processing Record 12 of Set 2 | codrington
# Processing Record 13 of Set 2 | pandan
# Processing Record 14 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 15 of Set 2 | taoudenni
# Processing Record 16 of Set 2 | iqaluit
# Processing Record 17 of Set 2 | hawaiian paradise park
# Processing Record 18 of Set 2 | macas
# Processing Record 19 of Set 2 | kolonia town
# Processing Record 20 of Set 2 | cole harbour
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | holualoa
# Processing Record 23 of Set 2 | fuling
# Processing Record 24 of Set 2 | afaahiti
# Processing Record 25 of Set 2 | beyneu
# Processing Record 26 of Set 2 | queenstown
# Processing Record 27 of Set 2 | alaghsas
# Processing Record 28 of Set 2 | gaspe
# Processing Record 29 of Set 2 | haiku-pauwela
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | puerto lempira
# Processing Record 32 of Set 2 | belyy yar
# Processing Record 33 of Set 2 | wailua homesteads
# Processing Record 34 of Set 2 | ushuaia
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | gadwal
# Processing Record 37 of Set 2 | ar ruways
# Processing Record 38 of Set 2 | gadzhiyevo
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | susuman
# Processing Record 41 of Set 2 | vilyuysk
# Processing Record 42 of Set 2 | pindiga
# Processing Record 43 of Set 2 | lazaro cardenas
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | zvishavane
# Processing Record 46 of Set 2 | kerikeri
# Processing Record 47 of Set 2 | atafu village
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | hovd
# Processing Record 0 of Set 3 | witu
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | st ives
# Processing Record 3 of Set 3 | flying fish cove
# Processing Record 4 of Set 3 | thunder bay
# Processing Record 5 of Set 3 | ixtapan de la sal
# Processing Record 6 of Set 3 | robore
# Processing Record 7 of Set 3 | alice springs
# Processing Record 8 of Set 3 | miyako
# Processing Record 9 of Set 3 | tongouson
# Processing Record 10 of Set 3 | fasa
# Processing Record 11 of Set 3 | tura
# Processing Record 12 of Set 3 | edinburgh of the seven seas
# Processing Record 13 of Set 3 | muang khong
# Processing Record 14 of Set 3 | labrador city
# Processing Record 15 of Set 3 | pisco
# Processing Record 16 of Set 3 | ntossoni
# City not found. Skipping...
# Processing Record 17 of Set 3 | dunedin
# Processing Record 18 of Set 3 | fredericton
# Processing Record 19 of Set 3 | laguna
# Processing Record 20 of Set 3 | anadyr
# Processing Record 21 of Set 3 | mansa
# Processing Record 22 of Set 3 | labytnangi
# Processing Record 23 of Set 3 | jilib
# Processing Record 24 of Set 3 | porto novo
# Processing Record 25 of Set 3 | bel ombre
# Processing Record 26 of Set 3 | guercif
# Processing Record 27 of Set 3 | kailua-kona
# Processing Record 28 of Set 3 | weno
# Processing Record 29 of Set 3 | nabire
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | kapa'a
# Processing Record 32 of Set 3 | badger
# Processing Record 33 of Set 3 | antsiranana
# Processing Record 34 of Set 3 | chibougamau
# Processing Record 35 of Set 3 | oranjemund
# Processing Record 36 of Set 3 | abohar
# Processing Record 37 of Set 3 | scottburgh
# Processing Record 38 of Set 3 | arcachon
# Processing Record 39 of Set 3 | sitka
# Processing Record 40 of Set 3 | vila do maio
# Processing Record 41 of Set 3 | blantyre
# Processing Record 42 of Set 3 | vorgashor
# Processing Record 43 of Set 3 | fort st. john
# Processing Record 44 of Set 3 | inhambane
# Processing Record 45 of Set 3 | yelizovo
# Processing Record 46 of Set 3 | forster
# Processing Record 47 of Set 3 | sonsorol village
# City not found. Skipping...
# Processing Record 48 of Set 3 | port douglas
# Processing Record 49 of Set 3 | kangding
# Processing Record 0 of Set 4 | ziri
# Processing Record 1 of Set 4 | selfoss
# Processing Record 2 of Set 4 | sparti
# Processing Record 3 of Set 4 | whitehorse
# Processing Record 4 of Set 4 | la foa
# Processing Record 5 of Set 4 | hamilton
# Processing Record 6 of Set 4 | katsuren-haebaru
# Processing Record 7 of Set 4 | praia da vitoria
# Processing Record 8 of Set 4 | kelo
# Processing Record 9 of Set 4 | happy valley-goose bay
# Processing Record 10 of Set 4 | la penita de jaltomba
# Processing Record 11 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | kurchatov
# Processing Record 14 of Set 4 | kijang
# Processing Record 15 of Set 4 | ocean shores
# Processing Record 16 of Set 4 | severnoye
# Processing Record 17 of Set 4 | kot mumin
# Processing Record 18 of Set 4 | qom
# Processing Record 19 of Set 4 | tralee
# Processing Record 20 of Set 4 | mount isa
# Processing Record 21 of Set 4 | kotido
# Processing Record 22 of Set 4 | nuuk
# Processing Record 23 of Set 4 | san giorgio di nogaro
# Processing Record 24 of Set 4 | keflavik
# Processing Record 25 of Set 4 | polyarnyy
# Processing Record 26 of Set 4 | al ain city
# Processing Record 27 of Set 4 | vorkuta
# Processing Record 28 of Set 4 | broken hill
# Processing Record 29 of Set 4 | ouani
# Processing Record 30 of Set 4 | along
# Processing Record 31 of Set 4 | novodvinsk
# Processing Record 32 of Set 4 | utrik
# Processing Record 33 of Set 4 | nova sintra
# Processing Record 34 of Set 4 | sur
# Processing Record 35 of Set 4 | baiti
# Processing Record 36 of Set 4 | faya-largeau
# Processing Record 37 of Set 4 | lingig
# Processing Record 38 of Set 4 | piton saint-leu
# Processing Record 39 of Set 4 | kingaroy
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | college
# Processing Record 42 of Set 4 | nuriootpa
# Processing Record 43 of Set 4 | ola
# Processing Record 44 of Set 4 | tazacorte
# Processing Record 45 of Set 4 | mar del plata
# Processing Record 46 of Set 4 | progreso
# Processing Record 47 of Set 4 | black point
# Processing Record 48 of Set 4 | punta arenas
# Processing Record 49 of Set 4 | kamalasai
# Processing Record 0 of Set 5 | bang saphan
# Processing Record 1 of Set 5 | zemio
# Processing Record 2 of Set 5 | padangsidempuan
# Processing Record 3 of Set 5 | huarmey
# Processing Record 4 of Set 5 | kill devil hills
# Processing Record 5 of Set 5 | darwin
# Processing Record 6 of Set 5 | la'ie
# Processing Record 7 of Set 5 | kataragama
# City not found. Skipping...
# Processing Record 8 of Set 5 | ust-nera
# Processing Record 9 of Set 5 | santyoku
# Processing Record 10 of Set 5 | lingcheng
# Processing Record 11 of Set 5 | seogwipo
# City not found. Skipping...
# Processing Record 12 of Set 5 | olgii
# City not found. Skipping...
# Processing Record 13 of Set 5 | recani
# Processing Record 14 of Set 5 | birao
# Processing Record 15 of Set 5 | leava
# Processing Record 16 of Set 5 | la tijera
# Processing Record 17 of Set 5 | brookings
# Processing Record 18 of Set 5 | enewetak
# Processing Record 19 of Set 5 | puttalam
# Processing Record 20 of Set 5 | daru
# Processing Record 21 of Set 5 | port glaud
# City not found. Skipping...
# Processing Record 22 of Set 5 | itoman
# Processing Record 23 of Set 5 | fortuna
# Processing Record 24 of Set 5 | winchester center
# Processing Record 25 of Set 5 | chonchi
# Processing Record 26 of Set 5 | ad dawadimi
# Processing Record 27 of Set 5 | dubbo
# Processing Record 28 of Set 5 | malango
# Processing Record 29 of Set 5 | harstad
# Processing Record 30 of Set 5 | port lincoln
# Processing Record 31 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 32 of Set 5 | manakara
# Processing Record 33 of Set 5 | talnakh
# Processing Record 34 of Set 5 | mikuni
# Processing Record 35 of Set 5 | cruzeiro do sul
# Processing Record 36 of Set 5 | hilo
# Processing Record 37 of Set 5 | newman
# Processing Record 38 of Set 5 | sao joao da barra
# Processing Record 39 of Set 5 | inirida
# Processing Record 40 of Set 5 | tosontsengel
# Processing Record 41 of Set 5 | howard springs
# Processing Record 42 of Set 5 | conception bay south
# Processing Record 43 of Set 5 | porto franco
# Processing Record 44 of Set 5 | radhanpur
# Processing Record 45 of Set 5 | khovd
# Processing Record 46 of Set 5 | luderitz
# Processing Record 47 of Set 5 | alofi
# Processing Record 48 of Set 5 | ovalle
# Processing Record 49 of Set 5 | saratamata
# City not found. Skipping...
# Processing Record 0 of Set 6 | aasiaat
# Processing Record 1 of Set 6 | pfronten
# Processing Record 2 of Set 6 | adrar
# Processing Record 3 of Set 6 | goz beida
# Processing Record 4 of Set 6 | ceeldheer
# Processing Record 5 of Set 6 | maralal
# Processing Record 6 of Set 6 | iskateley
# Processing Record 7 of Set 6 | viedma
# Processing Record 8 of Set 6 | la cruz
# Processing Record 9 of Set 6 | awjilah
# Processing Record 10 of Set 6 | caussade
# Processing Record 11 of Set 6 | aldan
# Processing Record 12 of Set 6 | pizarro
# Processing Record 13 of Set 6 | oualidia
# City not found. Skipping...
# Processing Record 14 of Set 6 | abadeh
# Processing Record 15 of Set 6 | tanah merah
# Processing Record 16 of Set 6 | farap
# Processing Record 17 of Set 6 | bondo
# Processing Record 18 of Set 6 | shengli
# Processing Record 19 of Set 6 | klyuchi
# Processing Record 20 of Set 6 | zhumysker
# Processing Record 21 of Set 6 | red hill
# Processing Record 22 of Set 6 | galle
# Processing Record 23 of Set 6 | vohipaho
# City not found. Skipping...
# Processing Record 24 of Set 6 | sarikei
# Processing Record 25 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 26 of Set 6 | abatskoye
# Processing Record 27 of Set 6 | tres de maio
# Processing Record 28 of Set 6 | freetown
# Processing Record 29 of Set 6 | san pedro pochutla
# Processing Record 30 of Set 6 | junction city
# Processing Record 31 of Set 6 | whistler
# Processing Record 32 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 33 of Set 6 | uturoa
# Processing Record 34 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 6 | sinabang
# Processing Record 36 of Set 6 | port macquarie
# Processing Record 37 of Set 6 | touros
# Processing Record 38 of Set 6 | serang
# Processing Record 39 of Set 6 | okha
# Processing Record 40 of Set 6 | lepsy
# Processing Record 41 of Set 6 | sao vicente
# Processing Record 42 of Set 6 | axum
# Processing Record 43 of Set 6 | at taj
# Processing Record 44 of Set 6 | korop
# Processing Record 45 of Set 6 | san luis
# Processing Record 46 of Set 6 | waingapu
# Processing Record 47 of Set 6 | kiraz
# Processing Record 48 of Set 6 | island harbour
# Processing Record 49 of Set 6 | rio grande
# Processing Record 0 of Set 7 | two rivers
# Processing Record 1 of Set 7 | vadso
# Processing Record 2 of Set 7 | amarante do maranhao
# Processing Record 3 of Set 7 | luanda
# Processing Record 4 of Set 7 | xindi
# Processing Record 5 of Set 7 | coquimbo
# Processing Record 6 of Set 7 | cururupu
# Processing Record 7 of Set 7 | acapulco de juarez
# Processing Record 8 of Set 7 | jasrasar
# Processing Record 9 of Set 7 | kristiansund
# Processing Record 10 of Set 7 | tajerouine
# Processing Record 11 of Set 7 | bhamo
# Processing Record 12 of Set 7 | lata
# Processing Record 13 of Set 7 | talara
# Processing Record 14 of Set 7 | tobelo
# Processing Record 15 of Set 7 | hounde
# Processing Record 16 of Set 7 | amahai
# Processing Record 17 of Set 7 | jambi city
# Processing Record 18 of Set 7 | nago
# Processing Record 19 of Set 7 | jalqani
# Processing Record 20 of Set 7 | remire-montjoly
# Processing Record 21 of Set 7 | hobyo
# Processing Record 22 of Set 7 | conceicao da barra
# Processing Record 23 of Set 7 | astrakhan
# Processing Record 24 of Set 7 | cockburn town
# Processing Record 25 of Set 7 | la passe
# Processing Record 26 of Set 7 | kalmunai
# Processing Record 27 of Set 7 | saipan
# Processing Record 28 of Set 7 | puerto leguizamo
# Processing Record 29 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 30 of Set 7 | olonkinbyen
# Processing Record 31 of Set 7 | yuzhno-kurilsk
# Processing Record 32 of Set 7 | kavaratti
# Processing Record 33 of Set 7 | amga
# Processing Record 34 of Set 7 | betio village
# Processing Record 35 of Set 7 | bani walid
# Processing Record 36 of Set 7 | taroa
# Processing Record 37 of Set 7 | ghanzi
# Processing Record 38 of Set 7 | zeya
# Processing Record 39 of Set 7 | sisimiut
# Processing Record 40 of Set 7 | mogocha
# Processing Record 41 of Set 7 | sainte-rose
# Processing Record 42 of Set 7 | axim
# Processing Record 43 of Set 7 | xucheng
# Processing Record 44 of Set 7 | saint-philippe
# Processing Record 45 of Set 7 | ceerigaabo
# Processing Record 46 of Set 7 | camayenne
# Processing Record 47 of Set 7 | el alto
# Processing Record 48 of Set 7 | batticaloa
# Processing Record 49 of Set 7 | kununurra
# Processing Record 0 of Set 8 | goondiwindi
# Processing Record 1 of Set 8 | murghob
# Processing Record 2 of Set 8 | iwon-up
# Processing Record 3 of Set 8 | yinchuan
# Processing Record 4 of Set 8 | neiafu
# Processing Record 5 of Set 8 | aleg
# Processing Record 6 of Set 8 | palikir - national government center
# Processing Record 7 of Set 8 | north platte
# Processing Record 8 of Set 8 | rajapur
# Processing Record 9 of Set 8 | mount gambier
# Processing Record 10 of Set 8 | kinna
# Processing Record 11 of Set 8 | prince rupert
# Processing Record 12 of Set 8 | harper
# Processing Record 13 of Set 8 | sorong
# Processing Record 14 of Set 8 | walvis bay
# Processing Record 15 of Set 8 | san clemente del tuyu
# Processing Record 16 of Set 8 | ulsteinvik
# Processing Record 17 of Set 8 | wenchang
# Processing Record 18 of Set 8 | itaituba
# Processing Record 19 of Set 8 | santo antonio
# Processing Record 20 of Set 8 | ponta delgada
# Processing Record 21 of Set 8 | bikenibeu village
# Processing Record 22 of Set 8 | san antonio de pale
# Processing Record 23 of Set 8 | conduaga
# Processing Record 24 of Set 8 | sandnessjoen
# Processing Record 25 of Set 8 | port-vila
# Processing Record 26 of Set 8 | tommot
# Processing Record 27 of Set 8 | paka
# Processing Record 28 of Set 8 | aleksandrovsk-sakhalinskiy
# Processing Record 29 of Set 8 | kone
# Processing Record 30 of Set 8 | ketchikan
# Processing Record 31 of Set 8 | guerrero negro
# Processing Record 32 of Set 8 | boyolangu
# Processing Record 33 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 34 of Set 8 | inarajan village
# Processing Record 35 of Set 8 | tofol
# Processing Record 36 of Set 8 | port alfred
# Processing Record 37 of Set 8 | gadani
# Processing Record 38 of Set 8 | balikpapan
# Processing Record 39 of Set 8 | nagqu
# Processing Record 40 of Set 8 | saldanha
# Processing Record 41 of Set 8 | loango
# Processing Record 42 of Set 8 | princeville
# Processing Record 43 of Set 8 | hithadhoo
# Processing Record 44 of Set 8 | nieuw amsterdam
# Processing Record 45 of Set 8 | usogorsk
# Processing Record 46 of Set 8 | nar'yan-mar
# Processing Record 47 of Set 8 | shush
# Processing Record 48 of Set 8 | lebu
# Processing Record 49 of Set 8 | tabou
# Processing Record 0 of Set 9 | fort mcmurray
# Processing Record 1 of Set 9 | phu ly
# Processing Record 2 of Set 9 | plouguerneau
# Processing Record 3 of Set 9 | koysinceq
# Processing Record 4 of Set 9 | yanbu
# Processing Record 5 of Set 9 | khadan khak
# Processing Record 6 of Set 9 | novoazovs'k
# Processing Record 7 of Set 9 | barra de santo antonio
# Processing Record 8 of Set 9 | qinzhou
# Processing Record 9 of Set 9 | znamenskoye
# Processing Record 10 of Set 9 | kunhegyes
# Processing Record 11 of Set 9 | mudurnu
# Processing Record 12 of Set 9 | greenville
# Processing Record 13 of Set 9 | iskushuban
# Processing Record 14 of Set 9 | malmberget
# Processing Record 15 of Set 9 | that phanom
# Processing Record 16 of Set 9 | athens
# Processing Record 17 of Set 9 | saint-pierre
# Processing Record 18 of Set 9 | namibe
# Processing Record 19 of Set 9 | vila franca do campo
# Processing Record 20 of Set 9 | kemijarvi
# Processing Record 21 of Set 9 | beihai
# Processing Record 22 of Set 9 | ikryanoye
# Processing Record 23 of Set 9 | juquitiba
# Processing Record 24 of Set 9 | chishtian
# Processing Record 25 of Set 9 | taoyuan city
# Processing Record 26 of Set 9 | tamanrasset
# Processing Record 27 of Set 9 | kasangulu
# Processing Record 28 of Set 9 | roma
# Processing Record 29 of Set 9 | wick
# Processing Record 30 of Set 9 | umm kaddadah
# Processing Record 31 of Set 9 | cabo san lucas
# Processing Record 32 of Set 9 | sarmiento
# Processing Record 33 of Set 9 | san diego de la union
# Processing Record 34 of Set 9 | rock springs
# Processing Record 35 of Set 9 | cill airne
# Processing Record 36 of Set 9 | qarah bagh
# Processing Record 37 of Set 9 | suntar
# Processing Record 38 of Set 9 | maceio
# Processing Record 39 of Set 9 | lakatoro
# Processing Record 40 of Set 9 | adh dhibiyah
# City not found. Skipping...
# Processing Record 41 of Set 9 | kourou
# Processing Record 42 of Set 9 | phan rang-thap cham
# Processing Record 43 of Set 9 | borgo
# Processing Record 44 of Set 9 | horta
# Processing Record 45 of Set 9 | fougamou
# Processing Record 46 of Set 9 | altayskoye
# Processing Record 47 of Set 9 | gornesti
# Processing Record 48 of Set 9 | tromso
# Processing Record 49 of Set 9 | rudbar
# Processing Record 0 of Set 10 | kargasok
# Processing Record 1 of Set 10 | vilyuchinsk
# Processing Record 2 of Set 10 | mahina
# Processing Record 3 of Set 10 | shiguai
# Processing Record 4 of Set 10 | broome
# Processing Record 5 of Set 10 | winejok
# City not found. Skipping...
# Processing Record 6 of Set 10 | upper dir
# Processing Record 7 of Set 10 | svatove
# Processing Record 8 of Set 10 | fairfield
# Processing Record 9 of Set 10 | takanabe
# Processing Record 10 of Set 10 | debre tabor
# Processing Record 11 of Set 10 | grootfontein
# Processing Record 12 of Set 10 | fairport
# Processing Record 13 of Set 10 | shalqar
# Processing Record 14 of Set 10 | lede
# Processing Record 15 of Set 10 | cambria
# Processing Record 16 of Set 10 | sudislavl'
# Processing Record 17 of Set 10 | dazhou
# Processing Record 18 of Set 10 | greenland
# Processing Record 19 of Set 10 | arraial do cabo
# Processing Record 20 of Set 10 | port moresby
# Processing Record 21 of Set 10 | wenatchee
# Processing Record 22 of Set 10 | pop
# Processing Record 23 of Set 10 | hotan
# Processing Record 24 of Set 10 | nikolayevsk-on-amure
# Processing Record 25 of Set 10 | jiangyou
# Processing Record 26 of Set 10 | zaozersk
# Processing Record 27 of Set 10 | tanrake village
# City not found. Skipping...
# Processing Record 28 of Set 10 | tucupita
# Processing Record 29 of Set 10 | bochum
# Processing Record 30 of Set 10 | suomussalmi
# Processing Record 31 of Set 10 | gotsucho
# Processing Record 32 of Set 10 | aksu
# Processing Record 33 of Set 10 | constantia
# Processing Record 34 of Set 10 | ngetkib
# Processing Record 35 of Set 10 | pangoa
# Processing Record 36 of Set 10 | tidjikja
# Processing Record 37 of Set 10 | byron bay
# Processing Record 38 of Set 10 | kibondo
# Processing Record 39 of Set 10 | aracati
# Processing Record 40 of Set 10 | argo
# Processing Record 41 of Set 10 | james island
# City not found. Skipping...
# Processing Record 42 of Set 10 | leninskoye
# Processing Record 43 of Set 10 | rikaze
# Processing Record 44 of Set 10 | alibag
# Processing Record 45 of Set 10 | cerro de ortega
# Processing Record 46 of Set 10 | varkaus
# Processing Record 47 of Set 10 | i-n-salah
# Processing Record 48 of Set 10 | tieli
# Processing Record 49 of Set 10 | estherville
# Processing Record 0 of Set 11 | san julian
# Processing Record 1 of Set 11 | viseu
# Processing Record 2 of Set 11 | kimbe
# Processing Record 3 of Set 11 | cradock
# Processing Record 4 of Set 11 | eureka
# Processing Record 5 of Set 11 | soissons
# Processing Record 6 of Set 11 | palmer
# Processing Record 7 of Set 11 | condom
# Processing Record 8 of Set 11 | jinshi
# Processing Record 9 of Set 11 | kalabo
# Processing Record 10 of Set 11 | san jose del guaviare
# Processing Record 11 of Set 11 | port sudan
# Processing Record 12 of Set 11 | richards bay
# Processing Record 13 of Set 11 | balabac
# Processing Record 14 of Set 11 | lompoc
# Processing Record 15 of Set 11 | arinos
# Processing Record 16 of Set 11 | rongelap
# Processing Record 17 of Set 11 | taltal
# Processing Record 18 of Set 11 | ji'an
# Processing Record 19 of Set 11 | vega de alatorre
# Processing Record 20 of Set 11 | vilhena
# Processing Record 21 of Set 11 | valparaiso
# Processing Record 22 of Set 11 | langepas
# Processing Record 23 of Set 11 | luganville
# Processing Record 24 of Set 11 | tanaina
# Processing Record 25 of Set 11 | severo-yeniseyskiy
# Processing Record 26 of Set 11 | sterlitamak
# Processing Record 27 of Set 11 | an nuhud
# Processing Record 28 of Set 11 | kruisfontein
# Processing Record 29 of Set 11 | masumbwe
# Processing Record 30 of Set 11 | chhatak
# Processing Record 31 of Set 11 | inari
# Processing Record 32 of Set 11 | akureyri
# Processing Record 33 of Set 11 | poxoreo
# Processing Record 34 of Set 11 | kui buri
# Processing Record 35 of Set 11 | belogradchik
# Processing Record 36 of Set 11 | perros-guirec
# Processing Record 37 of Set 11 | geraldton
# Processing Record 38 of Set 11 | santa maria
# Processing Record 39 of Set 11 | mana
# Processing Record 40 of Set 11 | muroto-misakicho
# Processing Record 41 of Set 11 | pudasjarvi
# Processing Record 42 of Set 11 | kiunga
# Processing Record 43 of Set 11 | port blair
# Processing Record 44 of Set 11 | hassi messaoud
# Processing Record 45 of Set 11 | pangody
# Processing Record 46 of Set 11 | nouadhibou
# Processing Record 47 of Set 11 | olenino
# Processing Record 48 of Set 11 | zambezi
# Processing Record 49 of Set 11 | leh
# Processing Record 0 of Set 12 | aykhal
# Processing Record 1 of Set 12 | huruta
# Processing Record 2 of Set 12 | taishan
# Processing Record 3 of Set 12 | sann
# Processing Record 4 of Set 12 | indramayu
# Processing Record 5 of Set 12 | bereznik
# Processing Record 6 of Set 12 | peniche
# Processing Record 7 of Set 12 | fale old settlement
# Processing Record 8 of Set 12 | lashio
# Processing Record 9 of Set 12 | xilin hot
# Processing Record 10 of Set 12 | eastham
# Processing Record 11 of Set 12 | aljezur
# Processing Record 12 of Set 12 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | kaa-khem
# Processing Record 14 of Set 12 | joao pinheiro
# Processing Record 15 of Set 12 | auki
# Processing Record 16 of Set 12 | fada
# Processing Record 17 of Set 12 | goure
# Processing Record 18 of Set 12 | ulladulla
# Processing Record 19 of Set 12 | iowa park
# Processing Record 20 of Set 12 | mata-utu
# Processing Record 21 of Set 12 | port saint john's
# Processing Record 22 of Set 12 | smithers
# Processing Record 23 of Set 12 | chernyshevskiy
# Processing Record 24 of Set 12 | ust'-ilimsk
# Processing Record 25 of Set 12 | magadan
# Processing Record 26 of Set 12 | hailar
# Processing Record 27 of Set 12 | kapuskasing
# Processing Record 28 of Set 12 | lodwar
# Processing Record 29 of Set 12 | san luis de la loma
# Processing Record 30 of Set 12 | longboat key
# Processing Record 31 of Set 12 | puerto armuelles
# Processing Record 32 of Set 12 | siasi
# Processing Record 33 of Set 12 | pemangkat
# Processing Record 34 of Set 12 | thanh pho uong bi
# Processing Record 35 of Set 12 | kushiro
# Processing Record 36 of Set 12 | hendek
# Processing Record 37 of Set 12 | christchurch
# Processing Record 38 of Set 12 | pali
# Processing Record 39 of Set 12 | noosa heads
# Processing Record 40 of Set 12 | cidreira
# Processing Record 41 of Set 12 | chui
# Processing Record 42 of Set 12 | nadym
# Processing Record 43 of Set 12 | wynyard
# Processing Record 44 of Set 12 | ardestan
# Processing Record 45 of Set 12 | crane
# Processing Record 46 of Set 12 | fiambala
# Processing Record 47 of Set 12 | bloomfield
# Processing Record 48 of Set 12 | villa la angostura
# Processing Record 49 of Set 12 | manacapuru
# Processing Record 0 of Set 13 | nemuro
# Processing Record 1 of Set 13 | usinsk
# Processing Record 2 of Set 13 | sabang
# Processing Record 3 of Set 13 | tobi village
# City not found. Skipping...
# Processing Record 4 of Set 13 | mitu
# Processing Record 5 of Set 13 | campbell river
# Processing Record 6 of Set 13 | hadibu
# Processing Record 7 of Set 13 | puerto baquerizo moreno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          adamstown -25.0660 -130.1015     21.53        58          77
# 1     puerto natales -51.7236  -72.4875      6.76        92         100
# 2         hammerfest  70.6634   23.6821      6.25       100          75
# 3  port-aux-francais -49.3500   70.2167      8.02        89         100
# 4         talcahuano -36.7167  -73.1167     15.82        82           0
#
#    Wind Speed Country        Date
# 0        7.69      PN  1683841698
# 1        0.88      CL  1683841939
# 2        3.09      NO  1683841735
# 3       19.08      TF  1683841693
# 4        3.60      CL  1683841816

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     21.53        58          77
# 1           puerto natales -51.7236  -72.4875      6.76        92         100
# 2               hammerfest  70.6634   23.6821      6.25       100          75
# 3        port-aux-francais -49.3500   70.2167      8.02        89         100
# 4               talcahuano -36.7167  -73.1167     15.82        82           0
#
#          Wind Speed Country        Date
# City_ID
# 0              7.69      PN  1683841698
# 1              0.88      CL  1683841939
# 2              3.09      NO  1683841735
# 3             19.08      TF  1683841693
# 4              3.60      CL  1683841816

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = city_data_df['Lat']
y_axis = city_data_df['Max Temp']
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
#today's date
today = time.gmtime()
today_formatted = time.strftime("%Y-%m-%d", today)
plt.title(f"City Latitude vs. Max Temperature ({today_formatted})")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Max Temperature (C)")


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
y_axis = city_data_df['Humidity']
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({today_formatted})")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
y_axis = city_data_df['Cloudiness']
plt.scatter(x_axis, y_axis, edgecolors="black")


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({today_formatted})")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
y_axis = city_data_df['Wind Speed']
plt.scatter(x_axis, y_axis, edgecolors="black")


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({today_formatted})")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                      hammerfest  70.6634   23.6821      6.25       100
# 7                        kamloops  50.6665 -120.3192     24.30        27
# 10                          laoag  18.1989  120.5936     25.95        83
# 11       petropavlovsk-kamchatsky  53.0452  158.6483      2.33        81
# 13                       mizunami  35.3667  137.2500     15.18        61
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                75        3.09      NO  1683841735
# 7                20        2.06      CA  1683841941
# 10               20        1.54      PH  1683841942
# 11               75        3.00      RU  1683841725
# 13               18        0.75      JP  1683841942

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     21.53        58          77
# 1           puerto natales -51.7236  -72.4875      6.76        92         100
# 3        port-aux-francais -49.3500   70.2167      8.02        89         100
# 4               talcahuano -36.7167  -73.1167     15.82        82           0
# 5                 hermanus -34.4187   19.2345     11.00        66         100
#
#          Wind Speed Country        Date
# City_ID
# 0              7.69      PN  1683841698
# 1              0.88      CL  1683841939
# 3             19.08      TF  1683841693
# 4              3.60      CL  1683841816
# 5              5.14      ZA  1683841719

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Max Temp']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.text(8, -10, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is -0.7868454337808765

# %%
# Linear regression on Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Max Temp']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.text(-55, 30, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.8138150707847828

# %% [markdown]
# ## Linear relationship
# ### Northern Hemisphere data
# * The r value for the northern hemisphere data shows a strong *negative* correlation as the r value is almost -1
# * The father north from the equator, the lower the maximum temperature
#
# ### Souther Hemisphere data
# * The r value for the southern hemisphere data shows a strong *positive* correlation as the r value is almost 1
# * The closer the city is to the equator, the higher the maximum temperature

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Humidity']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.text(40, 15, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.08438407961837696

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Humidity']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.text(-50, 20, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.13947694515069103

# %% [markdown]
# ## Linear Relationship
#
# ### Northern Hemisphere
# - The data for the nothern hemisphere has a very slight positive correlation as the r value of the line of best fit is very close to 0.
# - The more north from the equator the city is, it appears that the humidity is *slightly* higher than cities closer to the equator
#
# ### Southern Hemisphere
# - The data for the southern hemisphere has almost no correlation as the r value is even closer to 0 than the northern hemisphere data.
# - The humidity data as a whole appears to be rather inconclusive as there is no obvious trend between the distance from the equator and humidity for both north and south hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Cloudiness']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.text(50, 10, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.02967814329536

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Cloudiness']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.text(-50, 20, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.025518242954530986

# %% [markdown]
# ## Linear Relationship
# - The data for both the northern and southern hemispheres appears to show no correlation between the distance from the equator and the level of cloudiness.
# - There are cloudiness levels at both extremes regardless of latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Wind Speed']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.text(50, 10, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is 0.018083702506681783

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Wind Speed']

#create linregress stats variable and equation for line of best fit
linregress_stats = linregress(x_axis, y_axis)
fit_line = linregress_stats.slope*x_axis + linregress_stats.intercept

#plot the results
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit_line, color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.text(-50, 10, f"y = {linregress_stats.slope:0.2f}x + {linregress_stats.intercept:0.2f}", color="red", fontsize=14)
print(f"The r-value is {linregress_stats.rvalue}")
# Out:
# The r-value is -0.1813511751881505

# %% [markdown]
# ## Linear Relationship
# - The data for both the northern and southern hemispheres appears to show no correlation between the distance from the equator and wind speed. There are speeds ranging from still to very windy at all latitudes.
